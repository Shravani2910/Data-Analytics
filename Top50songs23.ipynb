# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("top_50_2023.csv")
df
# Out:
#            artist_name                                         track_name  \
# 0          Miley Cyrus                                            Flowers
# 1                  SZA                                          Kill Bill
# 2         Harry Styles                                          As It Was
# 3            Jung Kook                Seven (feat. Latto) (Explicit Ver.)
# 4       Eslabon Armado                                    Ella Baila Sola
# 5         Taylor Swift                                       Cruel Summer
# 6         Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 7                 Rema                      Calm Down (with Selena Gomez)
# 8             Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 9         Taylor Swift                                          Anti-Hero
# 10      Arctic Monkeys                                   I Wanna Be Yours
# 11             KAROL G                                                TQG
# ...

# %%
df.head()
# Out:
#       artist_name                           track_name  is_explicit  \
# 0     Miley Cyrus                              Flowers        False
# 1             SZA                            Kill Bill        False
# 2    Harry Styles                            As It Was        False
# 3       Jung Kook  Seven (feat. Latto) (Explicit Ver.)         True
# 4  Eslabon Armado                      Ella Baila Sola        False
#
#   album_release_date                                             genres  \
# 0         2023-08-18                                            ['pop']
# 1         2022-12-08                              ['pop', 'r&b', 'rap']
# 2         2022-05-20                                            ['pop']
# 3         2023-11-03                                          ['k-pop']
# 4         2023-04-28  ['corrido', 'corridos tumbados', 'sad sierreno...
#
#    danceability  valence  energy  loudness  acousticness  instrumentalness  \
# ...

# %%
df.tail()
# Out:
#            artist_name                        track_name  is_explicit  \
# 45  Tyler, The Creator  See You Again (feat. Kali Uchis)         True
# 46           Bad Bunny                   Me Porto Bonito         True
# 47            NewJeans                               OMG        False
# 48       Natanael Cano                               AMG         True
# 49                d4vd                 Romantic Homicide        False
#
#    album_release_date                                             genres  \
# 45         2017-07-21                                 ['hip hop', 'rap']
# 46         2022-05-06      ['reggaeton', 'trap latino', 'urbano latino']
# 47         2023-01-02                      ['k-pop', 'k-pop girl group']
# 48         2023-06-30  ['corrido', 'corridos tumbados', 'musica mexic...
# 49         2022-07-20                                    ['bedroom pop']
#
#     danceability  valence  energy  loudness  acousticness  instrumentalness  \
# ...

# %%
df.describe()
# Out:
#        danceability    valence     energy   loudness  acousticness  \
# count     50.000000  50.000000  50.000000  50.000000     50.000000
# mean       0.662580   0.510740   0.659880  -6.012440      0.253332
# std        0.123089   0.212346   0.121499   1.784443      0.222188
# min        0.445000   0.131000   0.417000 -10.613000      0.001460
# 25%        0.559500   0.344000   0.556750  -7.126000      0.086275
# 50%        0.647500   0.507000   0.678000  -5.639000      0.164500
# 75%        0.776500   0.654500   0.736500  -4.877000      0.405500
# max        0.911000   0.893000   0.965000  -2.810000      0.830000
#
#        instrumentalness   liveness  speechiness        key       tempo  \
# count         50.000000  50.000000    50.000000  50.000000   50.000000
# mean           0.020542   0.161280     0.083594   5.000000  124.069500
# std            0.093655   0.091988     0.077913   3.522522   31.396557
# min            0.000000   0.023200     0.025600   0.000000   67.033000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artist_name         50 non-null     object
#  1   track_name          50 non-null     object
#  2   is_explicit         50 non-null     bool
#  3   album_release_date  50 non-null     object
#  4   genres              50 non-null     object
#  5   danceability        50 non-null     float64
#  6   valence             50 non-null     float64
#  7   energy              50 non-null     float64
#  8   loudness            50 non-null     float64
#  9   acousticness        50 non-null     float64
#  10  instrumentalness    50 non-null     float64
#  11  liveness            50 non-null     float64
#  12  speechiness         50 non-null     float64
#  13  key                 50 non-null     int64
#  14  tempo               50 non-null     float64
# ...

# %%
df.drop_duplicates()
# Out:
#            artist_name                                         track_name  \
# 0          Miley Cyrus                                            Flowers
# 1                  SZA                                          Kill Bill
# 2         Harry Styles                                          As It Was
# 3            Jung Kook                Seven (feat. Latto) (Explicit Ver.)
# 4       Eslabon Armado                                    Ella Baila Sola
# 5         Taylor Swift                                       Cruel Summer
# 6         Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 7                 Rema                      Calm Down (with Selena Gomez)
# 8             Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 9         Taylor Swift                                          Anti-Hero
# 10      Arctic Monkeys                                   I Wanna Be Yours
# 11             KAROL G                                                TQG
# ...

# %%
df.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_44400\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# is_explicit              0.440000
# danceability             0.662580
# valence                  0.510740
# energy                   0.659880
# loudness                -6.012440
# acousticness             0.253332
# instrumentalness         0.020542
# liveness                 0.161280
# speechiness              0.083594
# key                      5.000000
# tempo                  124.069500
# mode                     0.560000
# duration_ms         200458.100000
# time_signature           3.900000
# popularity              88.100000
# dtype: float64

# %%
sns.histplot(df["popularity"],color="green",ls=':')
# Out:
# <Axes: xlabel='popularity', ylabel='Count'>

# %%
sns.scatterplot(df["genres"],color="blue")
# Out:
# <Axes: ylabel='genres'>

# %%
sns.scatterplot(df["is_explicit"],color="red")
# Out:
# <Axes: ylabel='is_explicit'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot.pie(xlabel="danceability")
#
# NameError: name 'plot' is not defined

# %%
sns.scatterplot(df["album_release_date"],color="blue")
# Out:
# <Axes: ylabel='album_release_date'>
